# %%
import runpy
runpy.run_path('generate_abbrev.py')
# Out:
# 2025-04-01 09:53:39.826 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-01 09:53:39.827 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-01 09:53:39.938
# ...
#   command:
#
#     streamlit run generate_abbrev.py [ARGUMENTS]
# 2025-04-01 09:53:39.938 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-01 09:53:39.939 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-01 09:53:39.939 Session state does not function when running a script without `streamlit run`
# 2025-04-01 09:53:39.940 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ...
